# %% [markdown]
# # Step 1 "Import Libraries"

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import sklearn 
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2 "Import Dataset"

# %%
full_data = pd.read_csv('IMDb Movies India.csv', encoding='ISO-8859-1')

# %%
full_data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %% [markdown]
# # Step 3 "Data Analysis and manipulation"

# %%
full_data.head(3)
# Out:
#                                  Name    Year Duration           Genre  \
# 0                                         NaN      NaN           Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min           Drama
# 2                         #Homecoming  (2021)   90 min  Drama, Musical
#
#    Rating Votes            Director       Actor 1            Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji             Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal     Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta  Plabita Borthakur
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
full_data.describe()
# Out:
#             Rating
# count  7919.000000
# mean      5.841621
# std       1.381777
# min       1.100000
# 25%       4.900000
# 50%       6.000000
# 75%       6.800000
# max      10.000000

# %%
full_data.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
sns.heatmap(full_data.isnull() , cmap ='tab20c_r' , yticklabels = False , cbar = False)
plt.title("Missing values")
plt.show()

# %%
 1.	#Extracting Independent and dependent Variable  
x= full_data.iloc[:, :-1].values  
y= full_data.iloc[:, 4].values  
print(x)
# Out:
# [[' ' nan nan ... 'J.S. Randhawa' 'Manmauji' 'Birbal']
#  ['#Gadhvi (He thought he was Gandhi)' '(2019)' '109 min' ...
#   'Gaurav Bakshi' 'Rasika Dugal' 'Vivek Ghamande']
#  ['#Homecoming' '(2021)' '90 min' ... 'Soumyajit Majumdar' 'Sayani Gupta'
#   'Plabita Borthakur']
#  ...
#  ['Zulmi Raj' '(2005)' nan ... 'Kiran Thej' 'Sangeeta Tiwari' nan]
#  ['Zulmi Shikari' '(1988)' nan ... nan nan nan]
#  ['Zulm-O-Sitam' '(1998)' '130 min' ... 'K.C. Bokadia' 'Dharmendra'
#   'Jaya Prada']]

# %%
print(y)
# Out:
# [nan 7.  nan ... nan nan 6.2]

# %%
# 1.	#Catgorical data  
#2.	from sklearn.preprocessing import LabelEncoder, OneHotEncoder  
#3.	labelencoder_x= LabelEncoder()  
#4.	x[:, 3]= labelencoder_x.fit_transform(x[:,3])  
#5.	onehotencoder= OneHotEncoder(categorical_features= [3])    
#6.	x= onehotencoder.fit_transform(x).toarray()

# %%
sns.boxplot(x = 'Rating' , y = 'Votes' , data = full_data , palette = "GnBu_d")
plt.show()

# %%
full_data.isnull()
# Out:
#         Name   Year  Duration  Genre  Rating  Votes  Director  Actor 1  \
# 0      False   True      True  False    True   True     False    False
# 1      False  False     False  False   False  False     False    False
# 2      False  False     False  False    True   True     False    False
# 3      False  False     False  False   False  False     False    False
# 4      False  False     False  False    True   True     False    False
# ...      ...    ...       ...    ...     ...    ...       ...      ...
# 15504  False  False      True  False   False  False     False    False
# 15505  False  False     False  False   False  False     False    False
# 15506  False  False      True  False    True   True     False    False
# 15507  False  False      True  False    True   True      True     True
# 15508  False  False     False  False   False  False     False    False
#
#        Actor 2  Actor 3
# 0        False    False
# 1        False    False
# 2        False    False
# ...

# %%
full_data.head(4)
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
#
#    Rating Votes            Director       Actor 1            Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji             Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal     Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta  Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik         Ishita Raj
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor

# %%
sns.heatmap(full_data.isnull() , yticklabels = False , cbar = False , cmap = "tab20c_r")
plt.title("Missing data :  training data ")
plt.show()

# %%
# dropping unneccessary coulmns 
full_data.drop('Name' , axis = 1 , inplace = True )

# %%
full_data.head(3)
# Out:
#      Year Duration           Genre  Rating Votes            Director  \
# 0     NaN      NaN           Drama     NaN   NaN       J.S. Randhawa
# 1  (2019)  109 min           Drama     7.0     8       Gaurav Bakshi
# 2  (2021)   90 min  Drama, Musical     NaN   NaN  Soumyajit Majumdar
#
#         Actor 1            Actor 2          Actor 3
# 0      Manmauji             Birbal  Rajendra Bhatia
# 1  Rasika Dugal     Vivek Ghamande    Arvind Jangid
# 2  Sayani Gupta  Plabita Borthakur       Roy Angana

# %%
# one hot encoding

# %%
import pandas as pd

# Assuming you have a DataFrame called 'data' with your dataset
data = pd.get_dummies(full_data, columns=["Genre", "Director", "Actor 1", "Actor 2", "Actor 3"])

# %%
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# Assuming 'full_data' is your DataFrame
full_data["Director"] = label_encoder.fit_transform(full_data["Director"])
full_data["Genre"] = label_encoder.fit_transform(full_data["Genre"])
full_data["Actor 1"] = label_encoder.fit_transform(full_data["Actor 1"])
full_data["Actor 2"] = label_encoder.fit_transform(full_data["Actor 2"])
full_data["Actor 3"] = label_encoder.fit_transform(full_data["Actor 3"])

# %%
full_data
# Out:
#          Year Duration  Genre  Rating Votes  Director  Actor 1  Actor 2  \
# 0         NaN      NaN    299     NaN   NaN      1926     2250      800
# 1      (2019)  109 min    299     7.0     8      1548     3280     4790
# 2      (2021)   90 min    351     NaN   NaN      5123     3713     2866
# 3      (2019)  110 min    228     4.4    35      3319     2917     1504
# 4      (2010)  105 min    299     NaN   NaN       385     3112     3462
# ...       ...      ...    ...     ...   ...       ...      ...      ...
# 15504  (1988)      NaN      0     4.6    11      2690     2586     4299
# 15505  (1999)  129 min     40     4.5   655      2499      227     4532
# 15506  (2005)      NaN      0     NaN   NaN      2424     3609     4891
# 15507  (1988)      NaN      0     NaN   NaN      5938     4718     4891
# 15508  (1998)  130 min     40     6.2    20      2195     1139     1589
#
#        Actor 3
# 0         3108
# 1          527
# 2         3450
# 3         4020
# 4          405
# ...

# %%
# remove rows
data.dropna(inplace=True)

# %%
full_data
# Out:
#          Year Duration  Genre  Rating Votes  Director  Actor 1  Actor 2  \
# 0         NaN      NaN    299     NaN   NaN      1926     2250      800
# 1      (2019)  109 min    299     7.0     8      1548     3280     4790
# 2      (2021)   90 min    351     NaN   NaN      5123     3713     2866
# 3      (2019)  110 min    228     4.4    35      3319     2917     1504
# 4      (2010)  105 min    299     NaN   NaN       385     3112     3462
# ...       ...      ...    ...     ...   ...       ...      ...      ...
# 15504  (1988)      NaN      0     4.6    11      2690     2586     4299
# 15505  (1999)  129 min     40     4.5   655      2499      227     4532
# 15506  (2005)      NaN      0     NaN   NaN      2424     3609     4891
# 15507  (1988)      NaN      0     NaN   NaN      5938     4718     4891
# 15508  (1998)  130 min     40     6.2    20      2195     1139     1589
#
#        Actor 3
# 0         3108
# 1          527
# 2         3450
# 3         4020
# 4          405
# ...

# %%
# Fill with a Specific Value
data.fillna(0, inplace=True)  # Filling NaN values with 0

# %%
full_data
# Out:
#          Year Duration  Genre  Rating Votes  Director  Actor 1  Actor 2  \
# 0         NaN      NaN    299     NaN   NaN      1926     2250      800
# 1      (2019)  109 min    299     7.0     8      1548     3280     4790
# 2      (2021)   90 min    351     NaN   NaN      5123     3713     2866
# 3      (2019)  110 min    228     4.4    35      3319     2917     1504
# 4      (2010)  105 min    299     NaN   NaN       385     3112     3462
# ...       ...      ...    ...     ...   ...       ...      ...      ...
# 15504  (1988)      NaN      0     4.6    11      2690     2586     4299
# 15505  (1999)  129 min     40     4.5   655      2499      227     4532
# 15506  (2005)      NaN      0     NaN   NaN      2424     3609     4891
# 15507  (1988)      NaN      0     NaN   NaN      5938     4718     4891
# 15508  (1998)  130 min     40     6.2    20      2195     1139     1589
#
#        Actor 3
# 0         3108
# 1          527
# 2         3450
# 3         4020
# 4          405
# ...

# %%
# Forward Fill or Backward Fill: If the missing values represent a time series or sequential data, you can use forward fill (propagate the last valid observation forward) or backward fill (propagate the next valid observation backward)
full_data.fillna(method='ffill', inplace=True)  # Forward fill

# %%
# Interpolation: For time series data, interpolation methods like linear interpolation can be used to estimate missing values based on the surrounding data points.
data.interpolate(method='linear', inplace=True)

# %%
full_data['Genre'].fillna('Unknown', inplace=True)

# %%
full_data.isnull().sum()
# Out:
# Year        1
# Duration    1
# Genre       0
# Rating      1
# Votes       1
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
columns_to_check = ["Year", "Duration", "Rating", "Votes"]
full_data.dropna(subset=columns_to_check , inplace = True )

# %%
full_data.isnull()
# Out:
#         Year  Duration  Genre  Rating  Votes  Director  Actor 1  Actor 2  \
# 1      False     False  False   False  False     False    False    False
# 2      False     False  False   False  False     False    False    False
# 3      False     False  False   False  False     False    False    False
# 4      False     False  False   False  False     False    False    False
# 5      False     False  False   False  False     False    False    False
# ...      ...       ...    ...     ...    ...       ...      ...      ...
# 15504  False     False  False   False  False     False    False    False
# 15505  False     False  False   False  False     False    False    False
# 15506  False     False  False   False  False     False    False    False
# 15507  False     False  False   False  False     False    False    False
# 15508  False     False  False   False  False     False    False    False
#
#        Actor 3
# 1        False
# 2        False
# 3        False
# 4        False
# ...

# %%
full_data.isnull().sum()
# Out:
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
x = full_data.select_dtypes(include=['object'])
print(x.columns )
# Out:
# Index(['Year', 'Duration', 'Votes'], dtype='object')

# %%
full_data
# Out:
#          Year Duration  Genre  Rating Votes  Director  Actor 1  Actor 2  \
# 1      (2019)  109 min    299     7.0     8      1548     3280     4790
# 2      (2021)   90 min    351     7.0     8      5123     3713     2866
# 3      (2019)  110 min    228     4.4    35      3319     2917     1504
# 4      (2010)  105 min    299     4.4    35       385     3112     3462
# 5      (1997)  147 min    197     4.7   827      3800      895      123
# ...       ...      ...    ...     ...   ...       ...      ...      ...
# 15504  (1988)  125 min      0     4.6    11      2690     2586     4299
# 15505  (1999)  129 min     40     4.5   655      2499      227     4532
# 15506  (2005)  129 min      0     4.5   655      2424     3609     4891
# 15507  (1988)  129 min      0     4.5   655      5938     4718     4891
# 15508  (1998)  130 min     40     6.2    20      2195     1139     1589
#
#        Actor 3
# 1          527
# 2         3450
# 3         4020
# 4          405
# 5         3829
# ...

# %%
sns.heatmap(full_data.isnull() , yticklabels = False , cbar = False , cmap = "tab20c_r")
plt.title("Missing data :  training data ")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame with 'Genre' column
top_50_genres = full_data['Genre'].value_counts().head(10)

# Define the size of the figure
plt.figure(figsize=(8, 8))

# Create an 'explode' list with values to separate individual slices using a loop
explode = [0.1] * len(top_50_genres)

top_50_genres.plot(kind='pie', autopct='%1.1f%%', explode=explode)

plt.title('Top 50 Genre Composition in the Dataset')
plt.ylabel('')  # Remove the 'Genre' label on the y-axis
plt.show()

# %%
full_data.shape
# Out:
# (15508, 9)

# %%
full_data.isnull().sum()
# Out:
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %% [markdown]
# # Step 4  "splitting data into train and test sets"

# %%
# split data to be used by model 
# Create martix of features 
x = full_data.drop('Rating' , axis = 1) # grabs everything else but "Rating"

# %%
y = full_data['Rating']

# %%
# use x and y variables to split data into training and testing set 
from sklearn.model_selection import train_test_split 
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = .20 , random_state = 101)
